# %%
#Import the diabetes dataset
# Replace non standarized missing values with standardized missing values
import pandas as pd
import numpy as np

missing_values = ["?","Unknown/Invalid"]
df = pd.read_csv("https://raw.githubusercontent.com/niteen11/DataAnalyticsAcademy/master/Python/dataset_diabetes/diabetic_data.csv",na_values=missing_values)
# Out:
# C:\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
# Read the dataset
df.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)    NaN
# 1        149190     55629189        Caucasian  Female  [10-20)    NaN
# 2         64410     86047875  AfricanAmerican  Female  [20-30)    NaN
# 3        500364     82442376        Caucasian    Male  [30-40)    NaN
# 4         16680     42519267        Caucasian    Male  [40-50)    NaN
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# ...

# %%
df.tail()
# Out:
#         encounter_id  patient_nbr             race  gender      age weight  \
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)    NaN
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)    NaN
# 101763     443854148     41088789        Caucasian    Male  [70-80)    NaN
# 101764     443857166     31693671        Caucasian  Female  [80-90)    NaN
# 101765     443867222    175429310        Caucasian    Male  [70-80)    NaN
#
#         admission_type_id  discharge_disposition_id  admission_source_id  \
# 101761                  1                         3                    7
# 101762                  1                         4                    5
# 101763                  1                         1                    7
# 101764                  2                         3                    7
# 101765                  1                         1                    7
#
#         time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# ...

# %%
# Check uniqueness of encounter_id column to consider it as an index
df['encounter_id'].is_unique
# Out:
# True

# %%
# Set the new index as encounter_id
df = df.set_index('encounter_id')

# %%
# Read the dataset to confirm the new index
df.head()
# Out:
#               patient_nbr             race  gender      age weight  \
# encounter_id
# 2278392           8222157        Caucasian  Female   [0-10)    NaN
# 149190           55629189        Caucasian  Female  [10-20)    NaN
# 64410            86047875  AfricanAmerican  Female  [20-30)    NaN
# 500364           82442376        Caucasian    Male  [30-40)    NaN
# 16680            42519267        Caucasian    Male  [40-50)    NaN
#
#               admission_type_id  discharge_disposition_id  \
# encounter_id
# 2278392                       6                        25
# 149190                        1                         1
# 64410                         1                         1
# 500364                        1                         1
# 16680                         1                         1
#
#               admission_source_id  time_in_hospital payer_code  ...  \
# encounter_id                                                    ...
# ...

# %%
# Setting to display all columns of a dataset
pd.set_option('display.max_columns', None)

# %%
# Read the dataset to identify all columns of a dataset
df.head()
# Out:
#               patient_nbr             race  gender      age weight  \
# encounter_id
# 2278392           8222157        Caucasian  Female   [0-10)    NaN
# 149190           55629189        Caucasian  Female  [10-20)    NaN
# 64410            86047875  AfricanAmerican  Female  [20-30)    NaN
# 500364           82442376        Caucasian    Male  [30-40)    NaN
# 16680            42519267        Caucasian    Male  [40-50)    NaN
#
#               admission_type_id  discharge_disposition_id  \
# encounter_id
# 2278392                       6                        25
# 149190                        1                         1
# 64410                         1                         1
# 500364                        1                         1
# 16680                         1                         1
#
#               admission_source_id  time_in_hospital payer_code  \
# encounter_id
# 2278392                         1                 1        NaN
# ...

# %%
# Removing unnecessary columns displaying codes, as no conclusion can be done from these columns such as admission_type_id, discharge_disposition_id, admission_source_id,payer_co

drop_cols = ['admission_type_id','discharge_disposition_id',"admission_source_id","payer_code"]
df.drop(drop_cols,inplace=True,axis=1)

# %%
# Read the dataset to see new set of columns
df.head()
# Out:
#               patient_nbr             race  gender      age weight  \
# encounter_id
# 2278392           8222157        Caucasian  Female   [0-10)    NaN
# 149190           55629189        Caucasian  Female  [10-20)    NaN
# 64410            86047875  AfricanAmerican  Female  [20-30)    NaN
# 500364           82442376        Caucasian    Male  [30-40)    NaN
# 16680            42519267        Caucasian    Male  [40-50)    NaN
#
#               time_in_hospital         medical_specialty  num_lab_procedures  \
# encounter_id
# 2278392                      1  Pediatrics-Endocrinology                  41
# 149190                       3                       NaN                  59
# 64410                        2                       NaN                  11
# 500364                       2                       NaN                  44
# 16680                        1                       NaN                  51
#
#               num_procedures  num_medications  number_outpatient  \
# ...

# %%
# Check for no of standardized missing values
df.isnull().sum().sum()
# Out:
# 152596

# %%
# drop the missing values
df=df.dropna()

# %%
# Data cleaning is completed.
df.shape
# Out:
# (1556, 45)

# %%
# Group patients by race

df1 = df.groupby(['race'])['patient_nbr'].count()

# %%
df1
# Out:
# race
# AfricanAmerican      49
# Asian                 1
# Caucasian          1485
# Other                21
# Name: patient_nbr, dtype: int64

# %%
df1.plot()
# Out:
# <AxesSubplot:xlabel='race'>

# %%
# Caucasian race has highest no of patients among all races 
df.head(1556)
# Out:
#               patient_nbr             race  gender      age     weight  \
# encounter_id
# 8042082          94466574        Caucasian    Male  [50-60)   [75-100)
# 8235036          79874631        Caucasian  Female  [60-70)     [0-25)
# 8421486          55628172        Caucasian  Female  [70-80)   [75-100)
# 8576406          80041266        Caucasian  Female  [80-90)    [50-75)
# 8620524          93126573        Caucasian  Female  [50-60)   [75-100)
# ...                   ...              ...     ...      ...        ...
# 436721264       123812618  AfricanAmerican    Male  [70-80)   [75-100)
# 437928656       117516146        Caucasian    Male  [30-40)  [100-125)
# 437959022         8420319        Caucasian    Male  [60-70)  [100-125)
# 439577312        97708986        Caucasian  Female  [70-80)    [50-75)
# 439606454       113392368  AfricanAmerican    Male  [60-70)   [75-100)
#
#               time_in_hospital       medical_specialty  num_lab_procedures  \
# encounter_id
# ...

# %%
# Setting to display all rows of a dataset
pd.set_option('display.max_rows', None)

# %%
# Caucasian race is chosen as feature for additional comparison
df2=df[df['race']=='Caucasian']

# %%
df2.head()
# Out:
#               patient_nbr       race  gender      age    weight  \
# encounter_id
# 8042082          94466574  Caucasian    Male  [50-60)  [75-100)
# 8235036          79874631  Caucasian  Female  [60-70)    [0-25)
# 8421486          55628172  Caucasian  Female  [70-80)  [75-100)
# 8576406          80041266  Caucasian  Female  [80-90)   [50-75)
# 8620524          93126573  Caucasian  Female  [50-60)  [75-100)
#
#               time_in_hospital medical_specialty  num_lab_procedures  \
# encounter_id
# 8042082                      2        Cardiology                  68
# 8235036                      5        Cardiology                  71
# 8421486                     11  InternalMedicine                  78
# 8576406                      9        Cardiology                  72
# 8620524                      6   Surgery-General                  41
#
#               num_procedures  num_medications  number_outpatient  \
# encounter_id
# ...

# %%
# Health statistics for Caucasian race group
# Patients that consulted a specific specialist
df3 = df2.groupby(['medical_specialty'])['num_medications'].sum().sort_values(ascending=False)

# %%
df3
# Out:
# medical_specialty
# Cardiology                 9663
# Surgery-General            6610
# InternalMedicine           5830
# Family/GeneralPractice     1878
# ObstetricsandGynecology     401
# Psychiatry                  228
# Dentistry                    24
# Pediatrics                   23
# Name: num_medications, dtype: int64

# %%
df3.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='medical_specialty'>

# %%
df3.describe()
# Out:
# count       8.00000
# mean     3082.12500
# std      3756.88676
# min        23.00000
# 25%       177.00000
# 50%      1139.50000
# 75%      6025.00000
# max      9663.00000
# Name: num_medications, dtype: float64

# %%
# Conclusion : Caucasian race is identified as the race having highest no of patients and with more no of patients consulting the
# cardiologist specialist.
